# %%
import pandas as pd
pd.set_option('display.height', 335)
# Out:
# height has been deprecated.

# %%
data = pd.read_csv("data/media-list2.csv")

# %%
data
# Out:
#                                             Titles       Type        Director  \
# 0                                     3 Billboards      movie             NaN
# 1                                          3 Women      movie             NaN
# 2                                          30 Rock         TV             NaN
# 3                     4 Months, 3 Weeks and 2 Days      movie             NaN
# 4                                           9 to 5      movie             NaN
# 5                                A Fantastic Woman      movie             NaN
# 6                 A Girl Walks Home Alone at Night      movie             NaN
# 7                            A League of their Own      movie             NaN
# 8                              A Raisin in the Sun      movie             NaN
# 9                                     A Seperation      movie             NaN
# 10                     A Woman Under the Influence      movie             NaN
# ...
