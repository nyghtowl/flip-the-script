# %%
import pandas as pd
pd.set_option('display.height', 335)
# Out:
# height has been deprecated.

# %%
data = pd.read_csv("data/media-list.csv")

# %%
data
# Out:
#                                             Titles  Movie/TV/Other  \
# 0                                     3 Billboards             NaN
# 1                                          3 Women             NaN
# 2                                          30 Rock             NaN
# 3                     4 Months, 3 Weeks and 2 Days             NaN
# 4                                           9 to 5             NaN
# 5                                A Fantastic Woman             NaN
# 6                 A Girl Walks Home Alone at Night             NaN
# 7                            A League of their Own             NaN
# 8                              A Raisin in the Sun             NaN
# 9                                     A Seperation             NaN
# 10                     A Woman Under the Influence             NaN
# 11                            A Women Called Moses             NaN
# 12                                         Accused             NaN
# ...
