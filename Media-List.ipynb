# %%
import pandas as pd
pd.set_option('display.height', 335)
# Out:
# height has been deprecated.

# %%
data = pd.read_csv("data/media-list3.csv")

# %%
data
# Out:
#      ID                                         Titles       Type  \
# 0   NaN                                   3 Billboards      movie
# 1   NaN                                        3 Women      movie
# 2   NaN                                        30 Rock         TV
# 3   NaN                   4 Months, 3 Weeks and 2 Days      movie
# 4   NaN                                         9 to 5      movie
# 5   NaN                              A Fantastic Woman      movie
# 6   NaN               A Girl Walks Home Alone at Night      movie
# 7   NaN                          A League of their Own      movie
# 8   NaN                            A Raisin in the Sun      movie
# 9   NaN                                   A Seperation      movie
# 10  NaN                    A Woman Under the Influence      movie
# 11  NaN                           A Women Called Moses         TV
# 12  NaN                                        Accused      movie
# ...

# %%
# Create JSON File for GitHub
data.to_json('data/fts.json', orient='records', lines=True)
# data.to_json('temp_split.json', orient='split')
# data.to_json('temp_ind.json', orient='index')
